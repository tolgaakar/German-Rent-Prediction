# %%
import json
from openai import OpenAI
import pandas as pd
import os
from tqdm import tqdm

OPENAI_API_KEY = '<YOUR_API_KEY>'
client = OpenAI(api_key=OPENAI_API_KEY)

batch_size = 50000 # Max limit for the Open AI Batch API

# %% [markdown]
# #### Load data

# %%
# Main data directory
data_directory = './'
# Cleaned data
data_file_name = 'df_clean.csv'

# Load data into DataFrame
pd.set_option('display.max_columns', None)
df = pd.read_csv(os.path.join(data_directory, data_file_name), lineterminator='\n')
df.head()
# Out:
#                 regio1                     heatingType telekomTvOffer  \
# 0  Nordrhein_Westfalen                 central_heating  ONE_YEAR_FREE
# 1              Sachsen                   floor_heating  ONE_YEAR_FREE
# 2               Bremen  self_contained_central_heating  ONE_YEAR_FREE
# 3               Bremen                 central_heating  ONE_YEAR_FREE
# 4    Baden_Württemberg                     oil_heating  ONE_YEAR_FREE
#
#    newlyConst  balcony  pricetrend  telekomUploadSpeed  totalRent  \
# 0       False    False        4.62           10.000000     840.00
# 1        True     True        2.72            2.400000    1300.00
# 2       False     True        2.46           28.920365     903.00
# 3       False     True        1.89            2.400000     584.25
# 4       False    False        3.77           40.000000     690.00
#
#    yearConstructed  hasKitchen  cellar  livingSpace       condition  \
# 0           1965.0       False    True        86.00       well_kept
# 1           2019.0       False    True        83.80  first_time_use
# 2           1950.0       False   False        84.97     refurbished
# 3           1959.0       False    True        60.30       well_kept
# 4           1970.0        True    True        53.00       well_kept
#
#                    streetPlain   lift    typeOfFlat  geo_plz  noRooms  \
# 0              Schüruferstraße  False  ground_floor    44269      4.0
# 1                    Turnerweg   True     apartment     1097      3.0
# 2  Hermann-Henrich-Meier-Allee  False     apartment    28213      3.0
# 3             Lesumer_Heerstr.  False  ground_floor    28717      3.0
# 4                  Hauptstraße  False   roof_storey    79211      2.0
#
#       floor  garden             regio2  \
# 0  1.000000    True           Dortmund
# 1  3.000000   False            Dresden
# 2  1.000000   False             Bremen
# 3  2.056523   False             Bremen
# 4  2.000000   False  Emmendingen_Kreis
#
#                                          description  \
# 0  Die ebenerdig zu erreichende Erdgeschosswohnun...
# 1  Der Neubau entsteht im Herzen der Dresdner Neu...
# 2  Es handelt sich hier um ein saniertes Mehrfami...
# 3  + Komfortabler Bodenbelag: Die Wohnung ist zus...
# 4  Diese ansprechende, lichtdurchflutete DG-Wohnu...
#
#                                           facilities
# 0  Die Wohnung ist mit Laminat ausgelegt. Das Bad...
# 1  * 9 m² Balkon\n* Bad mit bodengleicher Dusche,...
# 2  Diese Wohnung wurde neu saniert und ist wie fo...
# 3  Rollläden; Warmwasserbereiter; Kellerraum; Gas...
# 4                  Parkett, Einbauküche, kein Balkon

# %%
df.describe(include="all")
# Out:
#                      regio1      heatingType telekomTvOffer newlyConst  \
# count                173373           173373         173373     173373
# unique                   16               13              3          2
# top     Nordrhein_Westfalen  central_heating  ONE_YEAR_FREE      False
# freq                  41023           109060         167986     158299
# mean                    NaN              NaN            NaN        NaN
# std                     NaN              NaN            NaN        NaN
# min                     NaN              NaN            NaN        NaN
# 25%                     NaN              NaN            NaN        NaN
# 50%                     NaN              NaN            NaN        NaN
# 75%                     NaN              NaN            NaN        NaN
# max                     NaN              NaN            NaN        NaN
#
#        balcony     pricetrend  telekomUploadSpeed      totalRent  \
# count   173373  173373.000000       173373.000000  173373.000000
# unique       2            NaN                 NaN            NaN
# top       True            NaN                 NaN            NaN
# freq    110189            NaN                 NaN            NaN
# mean       NaN       3.478081           28.835647     845.354593
# std        NaN       1.921718           15.184535     577.176287
# min        NaN      -2.000000            1.000000       1.000000
# 25%        NaN       2.090000           10.000000     484.280000
# 50%        NaN       3.450000           40.000000     679.000000
# 75%        NaN       4.670000           40.000000    1030.000000
# max        NaN       8.560000           85.000000   19600.000000
#
#         yearConstructed hasKitchen  cellar    livingSpace  condition  \
# count     173373.000000     173373  173373  173373.000000     173373
# unique              NaN          2       2            NaN         10
# top                 NaN      False    True            NaN  well_kept
# freq                NaN     110458  116350            NaN      78130
# mean        1967.663555        NaN     NaN      72.434032        NaN
# std           35.928589        NaN     NaN      27.020618        NaN
# min         1856.000000        NaN     NaN       6.000000        NaN
# 25%         1956.000000        NaN     NaN      54.500000        NaN
# 50%         1966.880541        NaN     NaN      68.000000        NaN
# 75%         1994.000000        NaN     NaN      87.500000        NaN
# max         2080.000000        NaN     NaN     134.000000        NaN
#
#         streetPlain    lift typeOfFlat        geo_plz        noRooms  \
# count        173373  173373     173373  173373.000000  173373.000000
# unique        41778       2         10            NaN            NaN
# top     Hauptstraße   False  apartment            NaN            NaN
# freq          40252  128836     107548            NaN            NaN
# mean            NaN     NaN        NaN   37316.098660       2.605484
# std             NaN     NaN        NaN   27881.483794       0.907195
# min             NaN     NaN        NaN    1057.000000       1.000000
# 25%             NaN     NaN        NaN    9127.000000       2.000000
# 50%             NaN     NaN        NaN   39106.000000       3.000000
# 75%             NaN     NaN        NaN   57319.000000       3.000000
# max             NaN     NaN        NaN   99994.000000       4.500000
#
#                 floor  garden   regio2  \
# count   173373.000000  173373   173373
# unique            NaN       2      419
# top               NaN   False  Leipzig
# freq              NaN  136617     9789
# mean         2.044556     NaN      NaN
# std          1.317701     NaN      NaN
# min         -1.000000     NaN      NaN
# 25%          1.000000     NaN      NaN
# 50%          2.000000     NaN      NaN
# 75%          3.000000     NaN      NaN
# max          6.000000     NaN      NaN
#
#                                               description facilities
# count                                              173373     173373
# unique                                             145394     153883
# top     Das Objekt ist ein hochwertig saniertes und de...    Laminat
# freq                                                  199        193
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN

# %% [markdown]
# #### Create batches for the OpenAI Batch API

# %%
def create_batches(df, column, batch_size=50000):
    """ 
    Process the given column, prapare the batches for the Batch API, and finally save them in disk.
    """

    # Creating an array of json tasks
    tasks = []
    for index, row in df.iterrows():
        input = row[column]
        
        task = {
            "custom_id": f"{column}-{index}",
            "method": "POST",
            "url": "/v1/embeddings",
            "body": {
                # This is what you would have in your Embedding API call
                "model": "text-embedding-3-small",
                "input": input,
                "dimensions": 256
            }
        }
        
        tasks.append(task)
        
    num_files = len(tasks) // batch_size + 1
    for num_file in range(num_files):
        output_file = f'./batch_files/{column}_part{num_file}.jsonl'
        # make sure that the file does not exist, so don't add to an existing file
        if os.path.exists(output_file):
            os.remove(output_file)
        #write each embedding entry to a new line 
        with open(output_file, 'a', encoding='utf-8') as file:
            for task in tasks[batch_size*num_file : min(batch_size*(num_file+1),len(tasks))]:
                # Escaping ASCII is needed for correctly encoding German characters
                file.write(json.dumps(task, ensure_ascii=False) + '\n')
    
        # Sanity check, print the first 2 lines
        with open(output_file, 'r') as file:
            for line in file.readlines()[:2]:
                print(line)

# %%
create_batches(df, "description", batch_size)
# Out:
# {"custom_id": "description-0", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "Die ebenerdig zu erreichende Erdgeschosswohnung befindet sich in einem gepflegten 8-Familienhaus. Aufgrund der Hanglage bietet sich ein unverbaubarer Blick ins Grüne.", "dimensions": 256}}
#
# {"custom_id": "description-1", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "Der Neubau entsteht im Herzen der Dresdner Neustadt.\nDas Baugrundstück befindet sich inmitten einer sehr gefragten Lage.\nNicht nur die zentrale Lage und die schnelle öffentliche\nVerkehrsanbindung durch den zu Fuß erreichbaren Bahnhof, wie auch Nahverkehrsanbindung, sondern auch die Architektur werden diesen\nNeubaukomplex zu einem weiteren Highlight am Dresdner Wohnungsmarkt machen.\nHier entstehen 2- bis 4-Raum Wohnungen mit Wohnflächen zwischen 43 m² und 124 m². Jede Wohnung verfügt über eine Terrasse oder einen Balkon, die Erdgeschosswohnungen erhalten zusätzlich einen Gartenanteil. Die Räumlichkeiten bieten großzügig durchdachte, lichtdurchflutete Räume mit effektiv geschnittenen Grundrissen.", "dimensions": 256}}
#
# {"custom_id": "description-50000", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "Die Wohnung liegt im 1. Obergeschoss eines ruhigen, im Jahr 1997 erbauten Mehrfamilienhauses.", "dimensions": 256}}
#
# {"custom_id": "description-50001", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "Neuwertige Wohnungen im kernsanierten Mehrfamilienwohnhaus", "dimensions": 256}}
#
# {"custom_id": "description-100000", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "Das Mehrfamilienhaus wurde 1998 kernsaniert und das Dachgeschoss ausgebaut. Es entstanden 9 Wohnungen. Das Gebäude ist unterkellert.", "dimensions": 256}}
#
# {"custom_id": "description-100001", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "Massivbau \"zur alten Wache\",", "dimensions": 256}}
#
# {"custom_id": "description-150000", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "Diese attraktive, sanierte Wohnung in der ersten Etage kann zum 01.05.2020 bezogen werden. Zu dem Objekt zählen drei hübsche Zimmer. Beachten Sie auch, dass sich auf dem Balkon wunderbar vom Alltag erholen lässt.Zum Mietobjekt gehört eine Einzelgarage mit elektrischem Sektionaltor und eine Waschküche die gemeisam mit den beiden anderen Mietern genutzt wir.", "dimensions": 256}}
#
# {"custom_id": "description-150001", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "Zum 01.12.2019 können Sie diese freundliche, vollständig renovierte Erdgeschosswohnung beziehen, die durch eine gehobene Innenausstattung besticht. Die Wohnung ist über 7 Stufen erreichbar. Neben drei attraktiven Zimmern zählt zu der Wohnung außerdem ein separates Gäste-WC. Ein aktueller Energieausweis liegt vor. Der riesige Wohn-Essbereich 36 m² verfügt über eine Tür zur Westloggia, welche für ein echtes Wohlfühlambiente sorgt. Zu einem ganz besonderen Schmuckstück wird das Apartment dadurch, dass es außerdem über eine Ostloggia verfügt, welche an Kinder- und Eltern-Schlafzimmer angrenzt. Der Gemeinschaftsgarten gibt Ihnen zudem die Möglichkeit, dass Sie sich auch im Garten an der frischen Luft aufhalten können. Neben der Küche finden Sie einen großzügigen Vorratsraum und als weiteres Highlight eine Abstellkammer im Flur, welche als begehbarer Kleiderschrank genutzt werden kann, Zur Verfügung stehen Ihnen weiterhin ein Stellplatz für Ihr Auto direkt am Eingang und ein sehr großzügiger Kellerraum. Im Gemeinschaftskeller gibt es außerdem einen Fahrradkeller und einen Wäschetrockenraum.", "dimensions": 256}}

# %%
create_batches(df, "facilities", batch_size)
# Out:
# {"custom_id": "facilities-0", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "Die Wohnung ist mit Laminat ausgelegt. Das Badezimmer ist gefliest und verfügt über eine Wannendusche. Neue weiße Zimmertüren, ein Fliesenspiegel in der Küche und Fußleisten wurden kürzlich eingebaut.\nZur Wohnung gehört ein 10 m großer Keller. Eine Garage kann optional mitgemietet werden.", "dimensions": 256}}
#
# {"custom_id": "facilities-1", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "* 9 m² Balkon\n* Bad mit bodengleicher Dusche, Badewanne und Fenster\n* Gäste-WC\n* Waschmaschinenanschluss im Bad und im Waschkeller\n* Abstell\n* Fußbodenheizung\n* Fliesen & Echtholzparkett\n* elektrische Rollläden\n* Videotürsprechanlage mit Farbdisplay\n* Aufzug\n* KfW-Effizienshaus 55\n* Tiefgaragenstellplatz (Miete bereits in der Gesamtmiete enthalten)\n\n~ Der Mietbeginn: ca. Anfang 2020\n~ Baustelle: Betreten verboten! Besichtigungen noch nicht möglich!", "dimensions": 256}}
#
# {"custom_id": "facilities-50000", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "Das sonnige Wohnzimmer, der lange Flur und das Schlafzimmer haben einen neuen Laminatboden erhalten, die Küche zum Fliesenspiegel passende Bodenfliesen. \r\nDie gesamte Wohnung wurde fachmännisch gemalert und erstrahlt nun wieder in frischem Weiß.\r\n\r\nAlle Räume der Wohnung sind vom Flur aus begehbar. \r\nDas sonnige Wohnzimmer mit dem angrenzenden großen Balkon sind die Highlights der Wohnung und laden zum Verweilen ein. \r\nDas Schlafzimmer ist ca. 3 m breit und ca. 3,70 m breit - genug Platz für ein großes Bett und einen großen Kleiderschrank. \r\nDas geräumige Tageslichtbad ist mit einer Badewanne ausgestattet und hell gefliest.", "dimensions": 256}}
#
# {"custom_id": "facilities-50001", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "gehobene Ausstattung", "dimensions": 256}}
#
# {"custom_id": "facilities-100000", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "- 2 Zimmer\n- Tageslichtbad mit Wanne und Dusche\n- geräumige Küche\n- Laminat\n- Abstellkammer \n- Keller\n- Wäschetrockenraum", "dimensions": 256}}
#
# {"custom_id": "facilities-100001", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "Z-Heizung, Wohnküche, Bad mit Dusche und Waschmaschinenanschluss, Debelon-Fußboden, Abstellraum,", "dimensions": 256}}
#
# {"custom_id": "facilities-150000", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "In den Zimmern ist Eiche Echtholzparkett verlegt das Badezimmer hat elektrische Fußbdenheizung und es ist eine Klimaanlage im Wohnzimmer und Schlafzimmer voranden.Wenn möglich sollte die Küche des Vormieters übernommen werden.", "dimensions": 256}}
#
# {"custom_id": "facilities-150001", "method": "POST", "url": "/v1/embeddings", "body": {"model": "text-embedding-3-small", "input": "Hochwertiges Laminat in Wohnbereichen. \nFliesen in Küche, Gäste-WC und Bad. \nMan muss es einfach sehen...\nEs gibt einen kleinen Kinderspielplatz im Garten.", "dimensions": 256}}

# %% [markdown]
# #### Upload and process the prepared batches

# %%
# Upload batch files
batch_folder = './batch_files'
batch_input_files = []

files = os.listdir(batch_folder)
for file in tqdm(files, desc="Uploading files", unit="file"):
    batch_input_files.append(client.files.create(
        file=open(f'{batch_folder}/{file}', "rb"),
        purpose="batch"
    ))
# Out:
# Uploading files: 100%|████████████████████████████████████████████████████████████████████████████| 8/8 [03:19<00:00, 24.90s/file]

# %%
# Create the batch jobs
batch_file_ids= [batch_file.id for batch_file in batch_input_files] # Get the ids of the batch files
job_creations = []
for i,file_id in enumerate(batch_file_ids):
    job_creations.append(client.batches.create(
    input_file_id=file_id,
    endpoint="/v1/embeddings",
    completion_window="24h" # currently only 24h is supported 
    ))

# %%
# We can see here the jobs created, they start with validation
for job in job_creations:
    print(job)
# Out:
# Batch(id='batch_673a649633108190b847d1c38e23d7de', completion_window='24h', created_at=1731880086, endpoint='/v1/embeddings', input_file_id='file-IquT97bYps7n0ACRM4M8lE8c', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1731966486, failed_at=None, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))
# Batch(id='batch_673a6496c4d48190af9de4f29643f5c9', completion_window='24h', created_at=1731880086, endpoint='/v1/embeddings', input_file_id='file-f4OJ7juxHBi1J4lhfGqDY9nK', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1731966486, failed_at=None, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))
# Batch(id='batch_673a6497572081908b29db15af1e3678', completion_window='24h', created_at=1731880087, endpoint='/v1/embeddings', input_file_id='file-T6FDDEeUc5LnbAVGyFOSl30H', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1731966487, failed_at=None, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))
# Batch(id='batch_673a64982ee481909267bd7f448c03ef', completion_window='24h', created_at=1731880088, endpoint='/v1/embeddings', input_file_id='file-bqyqU8ze94KWdVT69AG1mRyi', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1731966488, failed_at=None, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))
# Batch(id='batch_673a6498d24c8190a5902430bc2f6fc3', completion_window='24h', created_at=1731880088, endpoint='/v1/embeddings', input_file_id='file-bRNjiou5NGwXGep8yc4zZJII', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1731966488, failed_at=None, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))
# Batch(id='batch_673a64997f308190910e2001e9759be0', completion_window='24h', created_at=1731880089, endpoint='/v1/embeddings', input_file_id='file-eOKYFSsMxwgBVJBPrgWd4qbk', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1731966489, failed_at=None, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))
# Batch(id='batch_673a6499f23881908506388756c01193', completion_window='24h', created_at=1731880090, endpoint='/v1/embeddings', input_file_id='file-Fsog41JTMzKRzs7jpRONWRAH', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1731966490, failed_at=None, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))
# Batch(id='batch_673a649aeba48190b09f1a2faa62e8d1', completion_window='24h', created_at=1731880091, endpoint='/v1/embeddings', input_file_id='file-RBxIYYXzuxUv3vwxSBQyYQCU', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1731966491, failed_at=None, finalizing_at=None, in_progress_at=None, metadata=None, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0))

# %% [markdown]
# #### Price Estimate

# %%
small_price_per_million = 0.010
large_price_per_million = 0.065
total_tokens_estimate = 173373 * 250
print("Estimated Total Token Count: ", total_tokens_estimate)
small_price_total = (total_tokens_estimate/1000000) * small_price_per_million
large_price_total = (total_tokens_estimate/1000000) * large_price_per_million

print("Estimated total price for the small model: ", small_price_total)
print("Estimated total price for the large model: ", large_price_total)
# Out:
# Estimated Total Token Count:  43343250
# Estimated total price for the small model:  0.4334325
# Estimated total price for the large model:  2.81731125
